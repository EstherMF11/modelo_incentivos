# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cobros = pd.read_csv("cobros_gestor.csv")
tasa = pd.read_csv("tasa_horaria.csv")
dimensionamiento = pd.read_csv("Dimensionamiento.csv")
vacaciones = pd.read_csv("vacaciones.csv")
segmento_maestra = pd.read_csv("segmento_mestra.csv")
absentismo = pd.read_csv("absentismo.csv")
calidad = pd.read_csv("calidad.csv")
eficacia = pd.read_csv("eficacias.csv")
normalizacion = pd.read_csv("normalizacion.csv")
santander = pd.read_csv("santandercf.csv")

# %%
tasa
dimensionamiento
vacaciones
segmento_maestra
absentismo
# Out:
#      usuario  tipo  total_solicitado
# 0  emolinero   dia                 1
# 1     jramon  hora                 5
# 2     jramon   dia                 1
# 3  emolinero  hora                 4

# %%
tasa
# Out:
#      usuario    segmento  tasa_horaria
# 0  emolinero          BI           1.0
# 1    sgarcia          BI           0.9
# 2     jramon          BI           0.8
# 3    sgarcia         ING           0.1
# 4     jramon         ING           0.2
# 5      alias  PREVENTIVO           1.0

# %%
rrhh = dimensionamiento.merge(vacaciones, on='usuario', how="left")
rrhh = rrhh.merge(absentismo, on='usuario', how="left")
conditions = [(rrhh.tipo == "hora")]
choicelist = [rrhh.total_solicitado]
rrhh['horas_absentismo'] = np.select(conditions, choicelist, default=rrhh.total_solicitado*rrhh.horas_dia)
rrhh['horas_no_efectivas'] = rrhh.horas_no_efectivas + rrhh.total_dias_solicitado*rrhh.horas_dia
rrhh = rrhh.groupby(['usuario', 'turno', 'horas_dia', 'horas_mes']).sum()[["horas_no_efectivas", 'horas_absentismo']].reset_index()
rrhh['horas_TH_trabajadas'] = rrhh.horas_mes - rrhh.horas_no_efectivas
rrhh['horas_trabajadas'] = rrhh.horas_mes - rrhh.horas_no_efectivas - rrhh.horas_absentismo
rrhh['presentismo'] = rrhh.horas_trabajadas / rrhh.horas_TH_trabajadas
rrhh['factor_corrector'] = rrhh.horas_TH_trabajadas / rrhh.horas_mes
rrhh = rrhh.merge(calidad, on='usuario', how="left")
rrhh
# Out:
#      usuario   turno  horas_dia  horas_mes  horas_no_efectivas  \
# 0      alias   Tarde        7.5        150                 0.0
# 1    bmartin  Mañana        7.0        140                 0.0
# 2     eloina  Mañana        7.5        150                 0.0
# 3  emolinero  Mañana        7.0        140                24.0
# 4     jramon   Tarde        7.5        150                32.0
# 5    sgarcia  Mañana        7.0        140                35.0
#
#    horas_absentismo  horas_TH_trabajadas  horas_trabajadas  presentismo  \
# 0               0.0                150.0             150.0     1.000000
# 1               0.0                140.0             140.0     1.000000
# 2               0.0                150.0             150.0     1.000000
# 3              11.0                116.0             105.0     0.905172
# 4              12.5                118.0             105.5     0.894068
# 5               0.0                105.0             105.0     1.000000
#
#    factor_corrector  pnt_calidad
# 0          1.000000         0.97
# 1          1.000000         0.95
# 2          1.000000         1.00
# 3          0.828571         0.95
# 4          0.786667         1.00
# 5          0.750000         1.00

# %%
cobros_totales = cobros.merge(segmento_maestra, on='segmento', how="left")
cobros_totales['usuario_segmento'] = cobros_totales.usuario+cobros_totales.segmento_maestra
cobros_totales = cobros_totales.groupby(['usuario', 'segmento_maestra', 'usuario_segmento'])['cobros_eur'].agg(
    ['sum','count']).reset_index()
cobros_totales
# Out:
#      usuario segmento_maestra usuario_segmento   sum  count
# 0  emolinero               BI      emolineroBI   280      3
# 1     jramon               BI         jramonBI   800      2
# 2     jramon              ING        jramonING  1300      4
# 3    sgarcia               BI        sgarciaBI   780      4
# 4    sgarcia              ING       sgarciaING   450      3

# %%
santander_gb = santander.groupby(['usuario', 'segmento_maestra', 'usuario_segmento'])['cobros_eur'].agg(
    ['sum','count']).reset_index()
santander_gb
# Out:
#    usuario segmento_maestra    usuario_segmento  sum  count
# 0  bmartin      SANTANDERCF  bmartinSANTANDERCF   30      1
# 1   eloina      SANTANDERCF   eloinaSANTANDERCF  600      1

# %%
cobros_totales = cobros_totales.merge(santander_gb, how='outer')
cobros_totales
# Out:
#      usuario segmento_maestra    usuario_segmento   sum  count
# 0  emolinero               BI         emolineroBI   280      3
# 1     jramon               BI            jramonBI   800      2
# 2     jramon              ING           jramonING  1300      4
# 3    sgarcia               BI           sgarciaBI   780      4
# 4    sgarcia              ING          sgarciaING   450      3
# 5    bmartin      SANTANDERCF  bmartinSANTANDERCF    30      1
# 6     eloina      SANTANDERCF   eloinaSANTANDERCF   600      1

# %%
tasa_corr = tasa.merge(segmento_maestra, on='segmento', how="left")
tasa_corr['usuario_segmento'] = tasa_corr.usuario+notas.segmento_maestra
tasa_corr = tasa_corr.groupby(['usuario', 'segmento_maestra', 'usuario_segmento']).sum().reset_index()
tasa_corr = tasa_corr.merge(santander[["usuario", "segmento_maestra", "usuario_segmento", "tasa_horaria"]], how='outer')
tasa_corr
# Out:
#      usuario segmento_maestra     usuario_segmento  tasa_horaria
# 0      alias       PREVENTIVO             aliasING           1.0
# 1  emolinero               BI  emolineroPREVENTIVO           1.0
# 2     jramon               BI             jramonBI           0.8
# 3     jramon              ING             jramonBI           0.2
# 4    sgarcia               BI            sgarciaBI           0.9
# 5    sgarcia              ING           sgarciaING           0.1
# 6    bmartin      SANTANDERCF   bmartinSANTANDERCF           1.0
# 7     eloina      SANTANDERCF    eloinaSANTANDERCF           1.0

# %%
notas = tasa_corr.merge(cobros_totales, how="left")
notas = notas.merge(eficacia, on=["usuario","segmento_maestra", "usuario_segmento", "tasa_horaria"], how="outer")
notas = notas.merge(rrhh[['usuario', 'horas_trabajadas', 'factor_corrector']], on='usuario', how='left')
notas['h_trab_seg'] = notas.tasa_horaria*notas.horas_trabajadas
notas['cobros_hora'] = notas['sum']/notas.h_trab_seg
notas['eficacia_hora'] = notas['eficacias']/notas.h_trab_seg
notas = notas.fillna(0)
notas['suma_notas'] = notas.cobros_hora + notas.eficacia_hora
notas = notas.merge(normalizacion, on="segmento_maestra", how='left')
notas
# Out:
# /home/dsc/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:1113: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#      usuario segmento_maestra     usuario_segmento  tasa_horaria    sum  \
# 0      alias       PREVENTIVO             aliasING           1.0    0.0
# 1  emolinero               BI  emolineroPREVENTIVO           1.0    0.0
# 2     jramon               BI             jramonBI           0.8  800.0
# 3     jramon              ING             jramonBI           0.2    0.0
# 4    sgarcia               BI            sgarciaBI           0.9  780.0
# 5    sgarcia              ING           sgarciaING           0.1  450.0
# 6    bmartin      SANTANDERCF   bmartinSANTANDERCF           1.0   30.0
# 7     eloina      SANTANDERCF    eloinaSANTANDERCF           1.0  600.0
# 8      alias       PREVENTIVO      aliasPREVENTIVO           1.0    0.0
#
#    count  eficacias  horas_trabajadas  factor_corrector  h_trab_seg  \
# 0    0.0        0.0             150.0          1.000000       150.0
# 1    0.0        0.0             105.0          0.828571       105.0
# 2    2.0        0.0             105.5          0.786667        84.4
# 3    0.0        0.0             105.5          0.786667        21.1
# 4    4.0        0.0             105.0          0.750000        94.5
# 5    3.0        0.0             105.0          0.750000        10.5
# 6    1.0        0.0             140.0          1.000000       140.0
# 7    1.0        0.0             150.0          1.000000       150.0
# 8    0.0       30.0             150.0          1.000000       150.0
#
#    cobros_hora  eficacia_hora  suma_notas  max  min
# 0     0.000000            0.0    0.000000  100   20
# 1     0.000000            0.0    0.000000   80    5
# 2     9.478673            0.0    9.478673   80    5
# 3     0.000000            0.0    0.000000   90   10
# 4     8.253968            0.0    8.253968   80    5
# 5    42.857143            0.0   42.857143   90   10
# 6     0.214286            0.0    0.214286   70    0
# 7     4.000000            0.0    4.000000   70    0
# 8     0.000000            0.2    0.200000  100   20

# %%
df = notas.copy()
df = df.groupby(["segmento_maestra"])["suma_notas"].agg(["max", "min"]).reset_index()
df['range_seg']=df['max']-df['min']
df = df.rename(columns={'max':'max_seg',
                   'min':'min_seg'})
df
# Out:
#   segmento_maestra    max_seg   min_seg  range_seg
# 0               BI   9.478673  0.000000   9.478673
# 1              ING  42.857143  0.000000  42.857143
# 2       PREVENTIVO   0.200000  0.000000   0.200000
# 3      SANTANDERCF   4.000000  0.214286   3.785714

# %%
notas = notas.merge(df, on='segmento_maestra', how='left')
conditions_range = [(notas.range_seg == 0)]
notas['notas_f_corr']=np.select(conditions_range,[notas['max']],default=(notas.suma_notas-notas.min_seg)*(notas['max']-notas['min'])/notas.range_seg+notas['min'])
notas
# Out:
#      usuario segmento_maestra     usuario_segmento  tasa_horaria    sum  \
# 0      alias       PREVENTIVO             aliasING           1.0    0.0
# 1  emolinero               BI  emolineroPREVENTIVO           1.0    0.0
# 2     jramon               BI             jramonBI           0.8  800.0
# 3     jramon              ING             jramonBI           0.2    0.0
# 4    sgarcia               BI            sgarciaBI           0.9  780.0
# 5    sgarcia              ING           sgarciaING           0.1  450.0
# 6    bmartin      SANTANDERCF   bmartinSANTANDERCF           1.0   30.0
# 7     eloina      SANTANDERCF    eloinaSANTANDERCF           1.0  600.0
# 8      alias       PREVENTIVO      aliasPREVENTIVO           1.0    0.0
#
#    count  eficacias  horas_trabajadas  factor_corrector  h_trab_seg  \
# 0    0.0        0.0             150.0          1.000000       150.0
# 1    0.0        0.0             105.0          0.828571       105.0
# 2    2.0        0.0             105.5          0.786667        84.4
# 3    0.0        0.0             105.5          0.786667        21.1
# 4    4.0        0.0             105.0          0.750000        94.5
# 5    3.0        0.0             105.0          0.750000        10.5
# 6    1.0        0.0             140.0          1.000000       140.0
# 7    1.0        0.0             150.0          1.000000       150.0
# 8    0.0       30.0             150.0          1.000000       150.0
#
#    cobros_hora  eficacia_hora  suma_notas  max  min    max_seg   min_seg  \
# 0     0.000000            0.0    0.000000  100   20   0.200000  0.000000
# 1     0.000000            0.0    0.000000   80    5   9.478673  0.000000
# 2     9.478673            0.0    9.478673   80    5   9.478673  0.000000
# 3     0.000000            0.0    0.000000   90   10  42.857143  0.000000
# 4     8.253968            0.0    8.253968   80    5   9.478673  0.000000
# 5    42.857143            0.0   42.857143   90   10  42.857143  0.000000
# 6     0.214286            0.0    0.214286   70    0   4.000000  0.214286
# 7     4.000000            0.0    4.000000   70    0   4.000000  0.214286
# 8     0.000000            0.2    0.200000  100   20   0.200000  0.000000
#
#    range_seg  notas_f_corr
# 0   0.200000     20.000000
# 1   9.478673      5.000000
# 2   9.478673     80.000000
# 3  42.857143     10.000000
# 4   9.478673     70.309524
# 5  42.857143     90.000000
# 6   3.785714      0.000000
# 7   3.785714     70.000000
# 8   0.200000    100.000000

# %% [markdown]
# Crear para cada usuario una fila con su nota global, crear fila por usuario con sus notas divididas

# %%
incentivos = notas.groupby(["usuario"])[['notas_f_corr']].sum().reset_index()
incentivos = pd.merge(rrhh[['usuario', 'presentismo', 'pnt_calidad']], incentivos[['usuario', 'notas_f_corr']], on='usuario', how="outer").fillna(0)
conditions_cal = [(incentivos.pnt_calidad >= 0.85)]
incentivos['cal'] = np.select(conditions_cal, [1], default=0)
conditions_pres = [(incentivos.presentismo >= 0.9)]
incentivos['pres'] = np.select(conditions_pres, [1], default=0)
incentivos['nota_final'] = incentivos.notas_f_corr*incentivos.presentismo*incentivos.pnt_calidad*incentivos.cal*incentivos.pres
incentivos
# Out:
#      usuario  presentismo  pnt_calidad  notas_f_corr  cal  pres  nota_final
# 0      alias     1.000000         0.97    120.000000    1     1  116.400000
# 1    bmartin     1.000000         0.95      0.000000    1     1    0.000000
# 2     eloina     1.000000         1.00     70.000000    1     1   70.000000
# 3  emolinero     0.905172         0.95      5.000000    1     1    4.299569
# 4     jramon     0.894068         1.00     90.000000    1     0    0.000000
# 5    sgarcia     1.000000         1.00    160.309524    1     1  160.309524

# %%
slots = incentivos[['usuario', 'nota_final']]
slots
# Out:
#      usuario  nota_final
# 0      alias  116.400000
# 1    bmartin    0.000000
# 2     eloina   70.000000
# 3  emolinero    4.299569
# 4     jramon    0.000000
# 5    sgarcia  160.309524

# %% [markdown]
# jerarquia

# %%
def hondt(votos, n):
    s = [0] * len(votos)
    for i in range(n):
        c = [v[j] / (s[j] + 1) for j in range(len(s))]
        s[c.index(max(c))] += 1
    return s

# %%
tamaño_slot = 20
bolsa = 5000
n = bolsa//tamaño_slot
v = slots.nota_final
slots['reparto'] = hondt(v,n)
slots['incentivos_pagados'] = [i * tamaño_slot for i in slots['reparto']]
slots
# Out:
# <ipython-input-54-288e004f0ec8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slots['reparto'] = hondt(v,n)
# <ipython-input-54-288e004f0ec8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slots['incentivos_pagados'] = [i * tamaño_slot for i in slots['reparto']]
#      usuario  nota_final  reparto  incentivos_pagados
# 0      alias  116.400000       83                1660
# 1    bmartin    0.000000        0                   0
# 2     eloina   70.000000       50                1000
# 3  emolinero    4.299569        3                  60
# 4     jramon    0.000000        0                   0
# 5    sgarcia  160.309524      114                2280

# %%
slots.plot(x='usuario',
           y='incentivos_pagados',
        kind='bar',
        stacked=False,
        title='Grouped Bar Graph with dataframe',
        figsize=(18,6),
        legend=True);
plt.ylabel('incentivos €')
# Out:
# Text(0, 0.5, 'incentivos €')
